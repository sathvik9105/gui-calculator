# %%
from tkinter import *
window=Tk()
window.title("Simple Caclulator")
e=Entry(window,width=25,borderwidth=5)
e.grid(row=0,column=0,columnspan=4,padx=10,pady=10)


def button_click(number):
    current=e.get()
    e.insert(END,number)
    
def button_clear():
    e.delete(0,END)

def button_add():
    first_number=e.get()
    global f_num
    global math
    math="addition"
    f_num=int(first_number)
    e.delete(0,END)

def button_sub():
    first_number=e.get()
    global f_num
    global math
    math="subtraction"
    f_num=int(first_number)
    e.delete(0,END)

def button_multiply():
    first_number=e.get()
    global f_num
    global math
    math="multiplication"
    f_num=int(first_number)
    e.delete(0,END)

def button_division():
    first_number=e.get()
    global f_num
    global math
    math="division"
    f_num=int(first_number)
    e.delete(0,END)

def button_percentage():
    first_number=e.get()
    global f_num
    global math
    math="percentage"
    f_num=int(first_number)
    e.delete(0,END)

def button_decimal():
    x=float(input())
    

    
def button_equal():
    second_number=e.get()
    e.delete(0,END)
    if math=="addition":
        e.insert(0,f_num+int(second_number))
    elif math=="subtraction":
        e.insert(0,f_num-int(second_number))
    elif math=="multiplication":
        e.insert(0,f_num*int(second_number))
    elif math=="division":
        e.insert(0,f_num/int(second_number))
    elif math=="percentage":
        e.insert(0,f_num/100*int(second_number))
    elif math=="decimal":
        e.insert(0,float(first_number))


button1=Button(window,text="1",padx=45,pady=25,command=lambda: button_click(1))
button2=Button(window,text="2",padx=45,pady=25,command=lambda: button_click(2))
button3=Button(window,text="3",padx=45,pady=25,command=lambda: button_click(3))
button4=Button(window,text="4",padx=45,pady=25,command=lambda: button_click(4))
button5=Button(window,text="5",padx=45,pady=25,command=lambda: button_click(5))
button6=Button(window,text="6",padx=45,pady=25,command=lambda: button_click(6))
button7=Button(window,text="7",padx=45,pady=25,command=lambda: button_click(7))
button8=Button(window,text="8",padx=45,pady=25,command=lambda: button_click(8))
button9=Button(window,text="9",padx=45,pady=25,command=lambda: button_click(9))
button0=Button(window,text="0",padx=45,pady=25,command=lambda: button_click(0))
buttondot=Button(window,text=".",padx=45,pady=25,command=lambda: button_decimal())
buttonpercent=Button(window,text="%",padx=45,pady=25,command=lambda: button_percentage())
buttonclear=Button(window,text="C",padx=45,pady=25,command=lambda: button_clear())
buttonbopen=Button(window,text="(",padx=45,pady=25,command=lambda: button_click('('))
buttonbclose=Button(window,text=")",padx=45,pady=25,command=lambda: button_click(')'))
buttonsum=Button(window,text="+",padx=45,pady=25,command=lambda: button_add())
buttonsubtract=Button(window,text="-",padx=45,pady=25,command=lambda: button_sub())
buttonproduct=Button(window,text="x",padx=45,pady=25,command=lambda: button_multiply())
buttondivision=Button(window,text="÷",padx=45,pady=25,command=lambda: button_division())
buttonequal=Button(window,text="=",padx=45,pady=25,command=lambda: button_equal())

button1.grid(row=4,column=1)
button2.grid(row=4,column=2)
button3.grid(row=4,column=3)

button4.grid(row=3,column=1)
button5.grid(row=3,column=2)
button6.grid(row=3,column=3)

button7.grid(row=2,column=1)
button8.grid(row=2,column=2)
button9.grid(row=2,column=3)

button0.grid(row=5,column=1)

buttondot.grid(row=5,column=2)
buttonpercent.grid(row=5,column=3)
buttonclear.grid(row=1,column=1)
buttonbopen.grid(row=1,column=2)
buttonbclose.grid(row=1,column=3)

buttonsum.grid(row=4,column=4)
buttonsubtract.grid(row=3,column=4)
buttonproduct.grid(row=2,column=4)
buttondivision.grid(row=1,column=4)
buttonequal.grid(row=5,column=4)


window.mainloop()
